# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'Data/height.csv')

# %%
data.head()
# Out:
#    ID  Height (cm)  Weight (kg)
# 0   1          160           55
# 1   2          170           68
# 2   3          165           60
# 3   4          175           72
# 4   5          180           80

# %%
df = pd.DataFrame(data)

# %%
# Split The Data
x = df[['Height (cm)']] # The Independent Features are always 2d Array or Data Frame a Irukanum intha line [[]] ipdi pota antha featues vanyhu DataFrame a Irukkunu Artham
y = df['Weight (kg)'] #The target variable it must be a 1D or Series

# %%
np.array(y).shape
# Out:
# (23,)

# %%
#Train and Split The Data
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
# Standardization
# The Height is (cm) and the Weight is Kg We cannot compare the Units for that we use the Standardization
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
summa_x_train = scaler.transform(X_train)
# Out:
# a:\ML-COMPLETE\ML-COMPLETE\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
summa_x_train
# Out:
# array([[-18.19451235],
#        [-18.19451235],
#        [-18.33706415],
#        [-18.25390894],
#        [-18.2301503 ],
#        [-18.43209868],
#        [-18.13511577],
#        [-18.07571919],
#        [-18.11135714],
#        [-18.3727021 ],
#        [-18.27766757],
#        [-18.20639167],
#        [-18.3727021 ],
#        [-18.28954688],
#        [-18.14699509],
#        [-18.01632261],
#        [-18.21827099]])

# %%
X_train
# Out:
# array([[ 0.30133158],
#        [ 0.30133158],
#        [-1.00657572],
#        [-0.24362979],
#        [-0.02564524],
#        [-1.87851392],
#        [ 0.84629296],
#        [ 1.39125433],
#        [ 1.06427751],
#        [-1.33355254],
#        [-0.46161434],
#        [ 0.19233931],
#        [-1.33355254],
#        [-0.57060662],
#        [ 0.73730068],
#        [ 1.93621571],
#        [ 0.08334703]])

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('The Slope Value',model.coef_)
# Out:
# array([10.54207981])

# %%
print('The Intercept Value ',model.intercept_)
# Out:
# The Intercept Value  65.1764705882353

# %%
#Plot the Bestfit Line
plt.scatter(X_train,y_train)
plt.plot(X_train,model.predict(X_train),color='red')

# %%
model.predict(X_train)
# Out:
# array([68.35313219, 68.35313219, 54.56506906, 62.60810589, 64.90611641,
#        45.37302696, 74.0981585 , 79.84318481, 76.39616902, 51.11805327,
#        60.31009536, 67.20412693, 51.11805327, 59.1610901 , 72.94915324,
#        85.58821111, 66.05512167])

# %%
# To check the Accuracy Metrics 
from sklearn.metrics import mean_squared_error,mean_absolute_error

MSE = mean_squared_error(y_test,model.predict(X_test))
MAE = mean_absolute_error(y_test,model.predict(X_test))
RMSE = np.sqrt(MSE)

print("MSE:",MSE)
print("MAE:",MAE)
print("RMSE:",RMSE)
# Out:
# MSE: 4.8541384864599175
# MAE: 2.0601570207168685
# RMSE: 2.2032109491512424

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test,model.predict(X_test))

# %%
score
# Out:
# 0.9587953347058342
